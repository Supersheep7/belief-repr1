# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Gpt-2-Large', 'Gpt-J-6B', 'Yi-6B', 'Yi-6B-instruct', 'Pythia-6.9B-deduped', 'Pythia-6.9B', 'Llama-2-13B', 'Llama-2-13B-instruct', 'Llama-3-8B', 'Llama-3-8B-instruct', 'Gemma-2-9B', 'Gemma-2-9B-instruct']
values = [58.3, 77, 63, 65.8, 71.6, 66.3, 87, 90.6, 90, 88, 91.5, 90]
colors = ['#FF9999', '#FF9999', '#66B3FF', '#66B3FF', '#99FF99', '#99FF99', '#E6E6FA', '#E6E6FA', '#E6E6FA','#E6E6FA', '#FFCC00',  '#FFCC00']

# Bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors, edgecolor='black')
cutoff_value = 75
plt.axhline(y=cutoff_value, color='red', linestyle='--', linewidth=1.5, label='Cutoff')
plt.text(-0.80, cutoff_value + 1, 'Cutoff', color='red', fontsize=10)


# Customizing plot aesthetics
plt.title('Top 3 Layers Probe Accuracy (Avg)', fontsize=16)
plt.xlabel('Models', fontsize=12)
plt.ylabel('Probe Accuracy', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylim(50, 100)  # Set y-axis range from 50 to 100

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import numpy as np
heads = np.array([99, 90, 97-17, 100-17, 43-28, 97-28, 86-22, 100-22, 17-8, 94-8, 28-14, 99-14])
resid = np.array([90, 97, 91-52, 84-52, 33-15, 87-15, 83-49, 99-49, 80-5, 71, 53-34, 99-34])

np.mean(heads-resid)
# Out:
# 9.166666666666666

# %%
behav = [(100-46+100-43)/200, (100+100-52)/200, (100-1+100-17)/200, (100-15+100-49)/200, (100-28+100-22)/200, (100-5+100-34)/200, (100-8+100-14)/200]
accs = [0.782, 0.901, 0.896, 0.885, 0.902, 0.915, 0.910]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
behav = [(100 - 46 + 100 - 43) / 200, (100 + 100 - 52) / 200, (100 - 1 + 100 - 17) / 200,
         (100 - 15 + 100 - 49) / 200, (100 - 28 + 100 - 22) / 200, (100 - 5 + 100 - 34) / 200,
         (100 - 8 + 100 - 14) / 200]
accs = [0.782, 0.901, 0.896, 0.885, 0.902, 0.915, 0.910]

# Indices for the x-axis
indices = np.arange(len(behav))
models = ['Gpt-J-6B', 'Llama-3.1-8B', 'Llama-3.1-8B-It', 'Llama-2-13B', 'Llama-2-13B-It', 'Gemma-2-9B', 'Gemma-2-9B-It']

# Bar width
bar_width = 0.4

# Plot
plt.figure(figsize=(10, 6))
plt.bar(indices - bar_width / 2, behav, bar_width, label='Behavioral Accuracy', color='blue', alpha=0.7)
plt.bar(indices + bar_width / 2, accs, bar_width, label='Probe Accuracy', color='orange', alpha=0.7)

# Labels and legend
plt.xlabel('Model', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Behavioral Accuracy vs Probe Accuracy', fontsize=16)
plt.xticks(indices, models)
plt.ylim(0.5, 1)  # Setting the y-axis range to start at 0.5
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
behav = [(100 - 46 + 100 - 43) / 200, (100 + 100 - 52) / 200, (100 - 1 + 100 - 17) / 200,
         (100 - 15 + 100 - 49) / 200, (100 - 28 + 100 - 22) / 200, (100 - 5 + 100 - 34) / 200,
         (100 - 8 + 100 - 14) / 200]
accs = [0.782, 0.901, 0.896, 0.885, 0.902, 0.915, 0.910]

# Indices for the x-axis
indices = np.arange(len(behav))
models = ['Gpt-J-6B', 'Llama-3.1-8B', 'Llama-3.1-8B-It', 'Llama-2-13B', 'Llama-2-13B-It', 'Gemma-2-9B', 'Gemma-2-9B-It']

# Bar width
bar_width = 0.4

# Plot
plt.figure(figsize=(12, 7))
plt.style.use('seaborn-darkgrid')  # Use a predefined style

# Bar colors
colors = ['#4E79A7', '#F28E2B']

# Plot bars
bars1 = plt.bar(indices - bar_width / 2, behav, bar_width, label='Behavioral Accuracy', color=colors[0], alpha=0.85, edgecolor='black', linewidth=0.7)
bars2 = plt.bar(indices + bar_width / 2, accs, bar_width, label='Probe Accuracy', color=colors[1], alpha=0.85, edgecolor='black', linewidth=0.7)

# Labels and legend
plt.xlabel('Model', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Behavioral Accuracy vs Probe Accuracy', fontsize=18, weight='bold', pad=20)
plt.xticks(indices, models, rotation=20, fontsize=12)
plt.ylim(0.5, 1)
plt.legend(fontsize=12, loc='upper left')


# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_8384\4099441081.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  # Use a predefined style

# %%
import pickle 

# Load the data from the pickle file
with open('llama_accuracies_mmp.pkl', 'rb') as file:
    mmp = pickle.load(file)

# %%
def pretty_line_mass(
    *lines,
    labels=None,
    title="Probe Accuracy on Residual Stream",
    x_axis="Layers",
    y_axis="Accuracy"
):
    """
    Create a pretty line plot with any number of lines.

    Parameters:
    - *lines: Any number of sequences (e.g., lists, numpy arrays) to plot.
    - labels: List of labels for each line. If None, default labels will be used.
    - title: Title of the plot.
    - x_axis: Label for the x-axis.
    - y_axis: Label for the y-axis.
    """
    fig, ax = plt.subplots(figsize=(12, 8), facecolor='w')
    ax.set_facecolor('#e0e0e0') 

    colors = ['#007acc',
        '#d60728',
        '#d65728', 
        '#d6b728', 
        '#2ca02c']
    markers = ['o']
    num_lines = len(lines)
    
    if labels is None:
        labels = [f"Line {i+1}" for i in range(num_lines)]
    
    for i, line in enumerate(lines):
        ax.plot(
            line,
            color=colors[i % len(colors)],
            alpha=0.5,
            marker=markers[i % len(markers)],
            markersize=5,
            linewidth=2.5,
            label=labels[i]
        )
    
    ax.set_title(title, fontsize=18, pad=20, weight='bold', color='#333333')
    ax.set_xlabel(x_axis, fontsize=14, labelpad=10, color='#333333')
    ax.set_ylabel(y_axis, fontsize=14, labelpad=10, color='#333333')

    ax.grid(visible=True, which='major', color='#f7f7f7', linewidth=1.5, linestyle='--')
    ax.tick_params(axis='both', which='major', labelsize=12, color='#555555')

    # Customize legend
    legend = ax.legend(fontsize=10.5, loc='upper left', frameon=True)
    legend.get_frame().set_facecolor('#ffffff')
    legend.get_frame().set_edgecolor('#e0e0e0')
    legend.get_frame().set_alpha(0.5)

    # Clean up spines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
import numpy as np

logreg = [0.51, 0.523, 0.525, 0.535, 0.59, 0.625, 0.70, 0.735, 0.765, 0.80, 0.835, 0.855, 0.898, 0.895, 0.895, 0.9, 0.878, 0.88, 0.878, 0.877, 0.868, 0.87, 0.87, 0.867, 0.869, 0.855, 0.86, 0.869, 0.87, 0.858, 0.875, 0.87]
mmp = [0.54, 0.535, 0.52, 0.535, 0.565, 0.575, 0.58, 0.62, 0.625, 0.64, 0.676, 0.737, 0.808, 0.778, 0.79, 0.775, 0.799, 0.77, 0.776, 0.79, 0.75, 0.76, 0.768, 0.79, 0.787, 0.783, 0.788, 0.784, 0.8, 0.78, 0.76, 0.78]
mlp_1 = [0.525, 0.527, 0.502, 0.51, 0.535, 0.646, 0.72, 0.798, 0.796, 0.848, 0.835, 0.851, 0.865, 0.867, 0.88, 0.878, 0.883, 0.88, 0.86, 0.85, 0.877, 0.861, 0.875, 0.869, 0.865, 0.87, 0.878, 0.873, 0.85, 0.845, 0.876, 0.876]
mlp_2 = [0.5403930131004366, 0.5207423580786026, 0.5327510917030568, 0.5403930131004366, 0.5283842794759825, 0.5141921397379913, 0.5960698689956332, 0.769650655021834, 0.7903930131004366, 0.7432314410480349, 0.7936681222707423, 0.8100436681222707, 0.8165938864628821, 0.8231441048034934, 0.8526200873362445, 0.8296943231441049, 0.8493449781659389, 0.824235807860262, 0.8329694323144105, 0.8395196506550219, 0.824235807860262, 0.8286026200873362, 0.7532314410480349, 0.8275109170305677, 0.8078602620087336, 0.8187772925764192, 0.7980349344978166, 0.8264192139737991, 0.8307860262008734, 0.8045851528384279, 0.7860262008733624, 0.8002183406113537]
mlp_3 = [0.5240174672489083, 0.5589519650655022, 0.5382096069868996, 0.527292576419214, 0.5502183406113537, 0.5611353711790393, 0.527292576419214, 0.7969432314410481, 0.767467248908297, 0.8056768558951966, 0.7991266375545851, 0.8100436681222707, 0.8296943231441049, 0.8318777292576419, 0.8329694323144105, 0.8384279475982532, 0.8373362445414847, 0.8417030567685589, 0.8362445414847162, 0.8275109170305677, 0.8198689956331878, 0.8362445414847162, 0.8111353711790393, 0.8253275109170306, 0.7947598253275109, 0.8078602620087336, 0.8253275109170306, 0.8176855895196506, 0.769650655021834, 0.7641921397379913, 0.7958515283842795, 0.7740174672489083]

top_5_logreg = np.flip(np.sort(logreg)[-5:])
top_5_mmp = np.flip(np.sort(mmp)[-5:])
top_5_mlp_1 = np.flip(np.sort(mlp_1)[-5:])
top_5_mlp_2 = np.flip(np.sort(mlp_2)[-5:])
top_5_mlp_3 = np.flip(np.sort(mlp_3)[-5:])
avg_top_5_logreg = np.mean(top_5_logreg)
avg_top_5_mmp = np.mean(top_5_mmp)
avg_top_5_mlp_1 = np.mean(top_5_mlp_1)
avg_top_5_mlp_2 = np.mean(top_5_mlp_2)
avg_top_5_mlp_3 = np.mean(top_5_mlp_3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample Data Structure
model_data = {
    "LogReg": list(top_5_logreg) + [avg_top_5_logreg],
    "MLP (1 HS)": list(top_5_mlp_1) + [avg_top_5_mlp_1],
    "MLP (2 HS)": list(top_5_mlp_2) + [avg_top_5_mlp_2],
    "MLP (3 HS)": list(top_5_mlp_3) + [avg_top_5_mlp_3],
    "MMP": list(top_5_mmp) + [avg_top_5_mmp],
}

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

bar_width = 0.15
x = np.arange(len(next(iter(model_data.values()))))  # get number of bars from any model
colors = ['#007acc',
        '#d60728',
        '#d65728', 
        '#d6b728', 
        '#2ca02c']

# Plot bars
for i, (model, values) in enumerate(model_data.items()):
    bars = ax.bar(
        x + i * bar_width, values,
        width=bar_width,
        label=model,
        color=colors[i % len(colors)],
        edgecolor='black',
        linewidth=0.8,
        alpha=0.7
    )


# Aesthetics
ax.set_xticks(x + bar_width * (len(model_data) - 1) / 2)
ax.set_xticklabels([f"Top {i+1}" for i in range(5)] + ["Avg"], fontsize=11)
ax.set_ylabel("Accuracy", fontsize=12)
ax.set_title("Top 5 Accuracies and Average per Model", fontsize=14, fontweight='bold')
ax.set_ylim(0.7, 1)

ax.legend(title="Model", fontsize=10, title_fontsize=11, loc='upper center', ncol=3)
ax.grid(axis='y', linestyle='--', alpha=0.5)
ax.set_axisbelow(True)

# Clean look
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
avg_top_5_logreg = np.mean(top_5_logreg)
avg_top_5_mmp = np.mean(top_5_mmp)
avg_top_5_mlp_1 = np.mean(top_5_mlp_1)
avg_top_5_mlp_2 = np.mean(top_5_mlp_2)
avg_top_5_mlp_3 = np.mean(top_5_mlp_3)

# %%
pretty_line_mass(logreg, mlp_1, mlp_2, mlp_3,  mmp, 
                 labels=['Logistic Regression', 'MLP (1 HS)', 'MLP (2 HS)', 'MLP (3 HS)', 'MMP'],
                 title='Probe Accuracy on Residual Stream (Llama)')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(mlp_3, label='Logistic Regression', marker='o', color='blue')
